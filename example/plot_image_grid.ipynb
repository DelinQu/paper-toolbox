# %%
import sys; sys.path.append("/home/qdl/Desktop/PJLAB/repo/matplotlib-for-paper")
from src import plot_grid_image
import glob

image_list = glob.glob('./images/*.JPEG')
figsize = (8, 32)
nrows, ncols = 2, 4
ylabels = ["ImageNet1K", "UCF101"]
xlabels = ["SOTA01", "SOTA02", "SOTA03", "OURS"]
axes_pad = 0.05
save_path = 'grid_image.pdf'

plot_grid_image.plot(image_list=image_list, figsize=figsize, nrows=nrows, ncols=ncols, xlabels=xlabels, ylabels=ylabels, axes_pad=axes_pad)
